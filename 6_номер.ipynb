# %%
# Задание task_01_06.
#
# Выполнила: Гафурова Н.А.
# Группа: ЦИБ-251


a = int(input())
b = int(input())
m = int(input())
n = int(input())

x = -b/a

is_ok = m<= x <= n

print("Попадает:", is_ok)


# --------------
# Пример вывода:
#
# Введите a = 1
# Введите b = 2
# Введите m = -5
# Введите n = 5
# Попадает: True
# Out:
# 1
# 2
# -5
# 5
# Попадает: True
